# %% [markdown]
# <a href="https://colab.research.google.com/github/swilsonmfc/anomaly/blob/master/DatasetSpeech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Speech
# ![alt text](https://greatspeech.com/wp-content/uploads/2015/05/public-speaking-3926344_19201-1030x687.jpg)

# %% [markdown]
# # Notes
# The real-world speech data set consists of 3686 segments of English speech spoken with different accents. This dataset is provided by the Speech Processing Group at Brno University of Technology, Czech Republic. The majority data corresponds to American accent and only 1.65% corresponds to one of seven other accents (these are referred to as outliers). The speech segments are represented by 400-dimensional so called i-vectors which are widely used state-of-the-art features for speaker and language recognition. It is a subset of data described [here](http://www.fit.vutbr.cz/research/groups/speech/publi/2012/brummer_odyssey2012_216-223-40.pdf).

# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np
from scipy.io import loadmat

# %% [markdown]
# # Data

# %%
# !wget https://www.dropbox.com/s/w6xv51ctea6uauc/speech.mat
# Out:
# --2020-07-03 12:45:17--  https://www.dropbox.com/s/w6xv51ctea6uauc/speech.mat
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.82.1, 2620:100:6032:1::a27d:5201
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.82.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/w6xv51ctea6uauc/speech.mat [following]
# --2020-07-03 12:45:17--  https://www.dropbox.com/s/raw/w6xv51ctea6uauc/speech.mat
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc01546912b68b3d8abf65f55261.dl.dropboxusercontent.com/cd/0/inline/A62OwlrVmsqJiFbFKSG-SqKE6FYDywhDD83mS1ZJTX__ZPZlkCXx4q6W6GHDFpdAgR8rCzDDvoflQ8nZRhIzCSHPYqDhYMgRFl19yc1ETD_UtQ/file# [following]
# --2020-07-03 12:45:17--  https://uc01546912b68b3d8abf65f55261.dl.dropboxusercontent.com/cd/0/inline/A62OwlrVmsqJiFbFKSG-SqKE6FYDywhDD83mS1ZJTX__ZPZlkCXx4q6W6GHDFpdAgR8rCzDDvoflQ8nZRhIzCSHPYqDhYMgRFl19yc1ETD_UtQ/file
# Resolving uc01546912b68b3d8abf65f55261.dl.dropboxusercontent.com (uc01546912b68b3d8abf65f55261.dl.dropboxusercontent.com)... 162.125.82.15, 2620:100:6032:15::a27d:520f
# Connecting to uc01546912b68b3d8abf65f55261.dl.dropboxusercontent.com (uc01546912b68b3d8abf65f55261.dl.dropboxusercontent.com)|162.125.82.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/A61wkCvi5u0OA8ScWj7mmMfmpR9BE4J6G6q5R27ZvL7ZNVOmb2uDS1Cdm8ohQQfV4sOIWBRC2vRHMqcIoLCn99qR0uz83L3FF0Mep-fdSMI1OPHgQaLrfwygtjQiheTTGk4Pc5KuTUYfw2j5QODZc4pL-x4DFj8WLJhaPzhAD65q43yivFt4vBcpdyH_fciPxfx8LhxkDEvGhYmOMqWut4IAIjk0-oteyn00lHEcCs4BZX5B7ZQM8ZjqwPbChZofVuFYP8CVYdmbsa1lBgWJAhtCsZzYEbALqjFstnBcXAsEApgR36T5RG6z8oG-WyzjHPH9X6IKR0tm44UEqoWei5aB/file [following]
# --2020-07-03 12:45:18--  https://uc01546912b68b3d8abf65f55261.dl.dropboxusercontent.com/cd/0/inline2/A61wkCvi5u0OA8ScWj7mmMfmpR9BE4J6G6q5R27ZvL7ZNVOmb2uDS1Cdm8ohQQfV4sOIWBRC2vRHMqcIoLCn99qR0uz83L3FF0Mep-fdSMI1OPHgQaLrfwygtjQiheTTGk4Pc5KuTUYfw2j5QODZc4pL-x4DFj8WLJhaPzhAD65q43yivFt4vBcpdyH_fciPxfx8LhxkDEvGhYmOMqWut4IAIjk0-oteyn00lHEcCs4BZX5B7ZQM8ZjqwPbChZofVuFYP8CVYdmbsa1lBgWJAhtCsZzYEbALqjFstnBcXAsEApgR36T5RG6z8oG-WyzjHPH9X6IKR0tm44UEqoWei5aB/file
# Reusing existing connection to uc01546912b68b3d8abf65f55261.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9509570 (9.1M) [application/octet-stream]
# Saving to: ‘speech.mat.1’
#
# speech.mat.1        100%[===================>]   9.07M  20.6MB/s    in 0.4s
#
# 2020-07-03 12:45:19 (20.6 MB/s) - ‘speech.mat.1’ saved [9509570/9509570]

# %%
mat = loadmat('speech.mat')

# %%
df = pd.DataFrame(mat['X'])
df = df.add_prefix('X')

# %%
df
# Out:
#            X0       X1       X2        X3  ...      X396      X397     X398     X399
# 0    -0.35069  0.52721 -1.62470 -1.334000  ... -0.607070  0.503820 -0.45571  0.86283
# 1    -0.42537 -0.08818  0.84575  0.881570  ... -1.069700 -0.024029  0.28696 -0.12374
# 2    -1.22100  0.43960 -0.06303  0.709530  ... -0.078469  0.097137 -0.55111  0.69951
# 3    -0.30132  0.55221  0.13769  0.715290  ... -0.070276 -0.539810 -1.10380  0.70562
# 4     0.31292  0.42762  0.50348  0.005489  ...  0.357150  1.278600 -0.40139  0.11640
# ...       ...      ...      ...       ...  ...       ...       ...      ...      ...
# 3681 -0.73029  0.41857 -0.41746 -0.454210  ...  0.467970  0.481060 -0.29457  0.55751
# 3682 -0.29375  1.46840 -0.28178 -1.411000  ... -0.343240 -0.023543 -1.57520 -0.37716
# 3683  0.94843  0.35538 -1.04010  0.292630  ...  0.197870  0.189580  1.04610 -0.30757
# 3684  1.49800 -0.66785  1.04800 -1.569300  ... -0.708690  0.369670 -0.49249 -0.40257
# 3685 -0.85682 -1.45620 -0.19547 -0.110290  ...  1.190900  0.487540 -0.14660 -0.76304
#
# [3686 rows x 400 columns]

# %% [markdown]
# # Outlier

# %%
outlier_df = pd.DataFrame(mat['y'])
outlier_df.columns = ['OUTLIER']

# %%
outlier_df.head()
# Out:
#    OUTLIER
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %% [markdown]
# # Save

# %%
export_df = pd.concat([df, outlier_df], axis=1)

# %%
export_df.head()
# Out:
#         X0       X1       X2        X3  ...      X397     X398     X399  OUTLIER
# 0 -0.35069  0.52721 -1.62470 -1.334000  ...  0.503820 -0.45571  0.86283        1
# 1 -0.42537 -0.08818  0.84575  0.881570  ... -0.024029  0.28696 -0.12374        1
# 2 -1.22100  0.43960 -0.06303  0.709530  ...  0.097137 -0.55111  0.69951        1
# 3 -0.30132  0.55221  0.13769  0.715290  ... -0.539810 -1.10380  0.70562        1
# 4  0.31292  0.42762  0.50348  0.005489  ...  1.278600 -0.40139  0.11640        1
#
# [5 rows x 401 columns]

# %%
# !mkdir -p data

# %%
export_df.to_csv('data/data_anomaly_speech.csv', index=0)
